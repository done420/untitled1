# %%
import os,sys
import tensorflow as tf
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
######## d2 mask rcnn log data

ade_ploy_eventfile = "E:/HongsenQu/result_ade_ploy_e5b4/events.out.tfevents.1592286671.zc.34928.0"




a = ['布艺沙发', '皮质沙发', '沙发组合', '沙发床', 'Minooti Baxter', 'FLEXFORM poliform', '罗奇堡', 'B&B等品牌标签'
'单椅', '吧椅', '矮墩', '圆凳', '脚凳', '办公椅', '沙滩椅', '户外椅',
'吊灯', '壁灯', '水晶灯', '台灯', '落地灯', '吸顶灯', '筒灯', '射灯', '户外灯', '动物灯', '造型灯', '大师灯',
'单人床', '双人床', '床头柜', '儿童床', '圆床', '罗汉床', '布艺床',
'餐桌', '书桌', '茶几', '边几', '吧台', '梳妆台', '餐桌椅', '茶桌',
'玄关柜', '电视柜', '装饰柜', '书柜', '衣柜', '储物柜', '酒柜', '鞋柜', '展示柜', '隔断柜', '博古架',
'饰品摆件', '墙饰', '装饰镜', '茶具', '艺术品', '镜子', '花卉', '插花', '花瓶',
'橱柜', '台盆', '浴缸', '马桶', '淋浴构件', '卫浴柜', '餐具', '瓷砖', '搭配', '岩板', '台面',
'隔断', '屏风', '门', '窗', '楼梯', '柱子', '栏杆', '雕花', '石膏线', 
'盆栽', '树木', '植物墙', '花艺']

for i in a:
    print(i+"\n")
# Out:
# 布艺沙发
#
# 皮质沙发
#
# 沙发组合
#
# 沙发床
#
# Minooti Baxter
#
# FLEXFORM poliform
#
# 罗奇堡
#
# B&B等品牌标签单椅
#
# 吧椅
#
# 矮墩
#
# 圆凳
#
# 脚凳
#
# 办公椅
#
# 沙滩椅
#
# 户外椅
#
# 吊灯
#
# 壁灯
#
# 水晶灯
#
# 台灯
#
# 落地灯
#
# 吸顶灯
#
# 筒灯
#
# 射灯
#
# 户外灯
#
# 动物灯
#
# 造型灯
#
# 大师灯
#
# 单人床
#
# 双人床
#
# 床头柜
#
# 儿童床
#
# 圆床
#
# 罗汉床
#
# 布艺床
#
# 餐桌
#
# 书桌
#
# 茶几
#
# 边几
#
# 吧台
#
# 梳妆台
#
# 餐桌椅
#
# 茶桌
#
# 玄关柜
#
# 电视柜
#
# 装饰柜
#
# 书柜
#
# 衣柜
#
# 储物柜
#
# 酒柜
#
# 鞋柜
#
# 展示柜
#
# 隔断柜
#
# 博古架
#
# 饰品摆件
#
# 墙饰
#
# 装饰镜
#
# 茶具
#
# 艺术品
#
# 镜子
#
# 花卉
#
# 插花
#
# 花瓶
#
# 橱柜
#
# 台盆
#
# 浴缸
#
# 马桶
#
# 淋浴构件
#
# 卫浴柜
#
# 餐具
#
# 瓷砖
#
# 搭配
#
# 岩板
#
# 台面
#
# 隔断
#
# 屏风
#
# 门
#
# 窗
#
# 楼梯
#
# 柱子
#
# 栏杆
#
# 雕花
#
# 石膏线
#
# 盆栽
#
# 树木
#
# 植物墙
#
# 花艺
